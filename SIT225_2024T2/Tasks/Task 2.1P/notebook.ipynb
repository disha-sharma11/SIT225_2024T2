# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("dht22_data.csv")

x = range(len(df))
plt.plot(x, df["Temperature (°C)"], label="Temperature", color="red")
plt.plot(x, df["Humidity (%)"], label="Humidity", color="blue")

plt.legend()
plt.show()
