# %%
import pandas as pd
import matplotlib.pyplot as plt

x_data = pd.read_csv("/Users/dishasharma/Documents/Coding/SIT225/Week8/activity1/Redmi Note 12 Pro 5G Thing-Accelerometer_X.csv")

x_data["time"] = pd.to_datetime(x_data["time"])

plt.figure(figsize=(8, 4))
plt.plot(x_data["time"], x_data["value"], label="Accel X", color="r")
plt.xlabel("Time")
plt.ylabel("Acceleration")
plt.title("Accelerometer X-Axis Data")
plt.legend()
plt.xticks(rotation=45) 
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

y_data = pd.read_csv("/Users/dishasharma/Documents/Coding/SIT225/Week8/activity1/Redmi Note 12 Pro 5G Thing-Accelerometer_Y.csv")

y_data["time"] = pd.to_datetime(y_data["time"])

plt.figure(figsize=(8, 4))
plt.plot(y_data["time"], y_data["value"], label="Accel Y", color="g")
plt.xlabel("Time")
plt.ylabel("Acceleration")
plt.title("Accelerometer Y-Axis Data")
plt.legend()
plt.xticks(rotation=45)  
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

z_data = pd.read_csv("/Users/dishasharma/Documents/Coding/SIT225/Week8/activity1/Redmi Note 12 Pro 5G Thing-Accelerometer_Z.csv")

z_data["time"] = pd.to_datetime(z_data["time"])

plt.figure(figsize=(8, 4))
plt.plot(z_data["time"], z_data["value"], label="Accel Z", color="b")
plt.xlabel("Time")
plt.ylabel("Acceleration")
plt.title("Accelerometer Z-Axis Data")
plt.legend()
plt.xticks(rotation=45) 
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

x_data = pd.read_csv("/Users/dishasharma/Documents/Coding/SIT225/Week8/activity1/Redmi Note 12 Pro 5G Thing-Accelerometer_X.csv")
y_data = pd.read_csv("/Users/dishasharma/Documents/Coding/SIT225/Week8/activity1/Redmi Note 12 Pro 5G Thing-Accelerometer_Y.csv")
z_data = pd.read_csv("/Users/dishasharma/Documents/Coding/SIT225/Week8/activity1/Redmi Note 12 Pro 5G Thing-Accelerometer_Z.csv")

x_data["time"] = pd.to_datetime(x_data["time"])
y_data["time"] = pd.to_datetime(y_data["time"])
z_data["time"] = pd.to_datetime(z_data["time"])

combined_data = x_data.merge(y_data, on="time", suffixes=("_X", "_Y"))
combined_data = combined_data.merge(z_data, on="time")
combined_data.rename(columns={"value": "Accel_Z"}, inplace=True)

plt.figure(figsize=(10, 5))
plt.plot(combined_data["time"], combined_data["value_X"], label="Accel X", color="r")
plt.plot(combined_data["time"], combined_data["value_Y"], label="Accel Y", color="g")
plt.plot(combined_data["time"], combined_data["Accel_Z"], label="Accel Z", color="b")

plt.xlabel("Time")
plt.ylabel("Acceleration")
plt.title("Combined Accelerometer Data Over Time")
plt.legend()
plt.xticks(rotation=45)  
plt.show()
